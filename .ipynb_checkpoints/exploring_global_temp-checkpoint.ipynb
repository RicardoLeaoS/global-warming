# %% [markdown]
# # importing

# %%
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np
import datetime

from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.seasonal import seasonal_decompose
sns.set(style="darkgrid")

# %%
global_temp_df = pd.read_csv('data/GlobalTemperatures.csv')

# %% [markdown]
# # exploring global temp

# %%
global_temp_df.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
global_temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3192 entries, 0 to 3191
# Data columns (total 9 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   dt                                         3192 non-null   object
#  1   LandAverageTemperature                     3180 non-null   float64
#  2   LandAverageTemperatureUncertainty          3180 non-null   float64
#  3   LandMaxTemperature                         1992 non-null   float64
#  4   LandMaxTemperatureUncertainty              1992 non-null   float64
#  5   LandMinTemperature                         1992 non-null   float64
#  6   LandMinTemperatureUncertainty              1992 non-null   float64
#  7   LandAndOceanAverageTemperature             1992 non-null   float64
#  8   LandAndOceanAverageTemperatureUncertainty  1992 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 224.6+ KB

# %%
global_temp_df.describe()
# Out:
#        LandAverageTemperature  LandAverageTemperatureUncertainty  \
# count             3180.000000                        3180.000000
# mean                 8.374731                           0.938468
# std                  4.381310                           1.096440
# min                 -2.080000                           0.034000
# 25%                  4.312000                           0.186750
# 50%                  8.610500                           0.392000
# 75%                 12.548250                           1.419250
# max                 19.021000                           7.880000
#
#        LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# count         1992.000000                    1992.000000         1992.000000
# mean            14.350601                       0.479782            2.743595
# std              4.309579                       0.583203            4.155835
# ...

# %%
global_temp_df.isnull().any()
# Out:
# dt                                           False
# LandAverageTemperature                        True
# LandAverageTemperatureUncertainty             True
# LandMaxTemperature                            True
# LandMaxTemperatureUncertainty                 True
# LandMinTemperature                            True
# LandMinTemperatureUncertainty                 True
# LandAndOceanAverageTemperature                True
# LandAndOceanAverageTemperatureUncertainty     True
# dtype: bool

# %%
global_temp_df.isnull().mean()
# Out:
# dt                                           0.000000
# LandAverageTemperature                       0.003759
# LandAverageTemperatureUncertainty            0.003759
# LandMaxTemperature                           0.375940
# LandMaxTemperatureUncertainty                0.375940
# LandMinTemperature                           0.375940
# LandMinTemperatureUncertainty                0.375940
# LandAndOceanAverageTemperature               0.375940
# LandAndOceanAverageTemperatureUncertainty    0.375940
# dtype: float64

# %%
years = np.unique(global_temp_df.dt.apply(lambda x: x[:4]))

# %%
global_temp_df['dt'] = global_temp_df['dt'].apply(lambda x : datetime.datetime.strptime(x, '%Y-%m-%d'))

# %%
global_temp_df['year'] = global_temp_df['dt'].apply(lambda x: x.year)

# %%
global_temp_df.isnull().mean()
# Out:
# dt                                           0.000000
# LandAverageTemperature                       0.003759
# LandAverageTemperatureUncertainty            0.003759
# LandMaxTemperature                           0.375940
# LandMaxTemperatureUncertainty                0.375940
# LandMinTemperature                           0.375940
# LandMinTemperatureUncertainty                0.375940
# LandAndOceanAverageTemperature               0.375940
# LandAndOceanAverageTemperatureUncertainty    0.375940
# year                                         0.000000
# dtype: float64

# %%
global_temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3192 entries, 0 to 3191
# Data columns (total 10 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   dt                                         3192 non-null   datetime64[ns]
#  1   LandAverageTemperature                     3180 non-null   float64
#  2   LandAverageTemperatureUncertainty          3180 non-null   float64
#  3   LandMaxTemperature                         1992 non-null   float64
#  4   LandMaxTemperatureUncertainty              1992 non-null   float64
#  5   LandMinTemperature                         1992 non-null   float64
#  6   LandMinTemperatureUncertainty              1992 non-null   float64
#  7   LandAndOceanAverageTemperature             1992 non-null   float64
#  8   LandAndOceanAverageTemperatureUncertainty  1992 non-null   float64
# ...

# %%
global_temp_df.describe()
# Out:
#        LandAverageTemperature  LandAverageTemperatureUncertainty  \
# count             3180.000000                        3180.000000
# mean                 8.374731                           0.938468
# std                  4.381310                           1.096440
# min                 -2.080000                           0.034000
# 25%                  4.312000                           0.186750
# 50%                  8.610500                           0.392000
# 75%                 12.548250                           1.419250
# max                 19.021000                           7.880000
#
#        LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# count         1992.000000                    1992.000000         1992.000000
# mean            14.350601                       0.479782            2.743595
# std              4.309579                       0.583203            4.155835
# ...

# %% [markdown]
# ### missing data

# %%
missing_value_cols = [x for x in global_temp_df.columns if global_temp_df[x].isnull().any()]

# %%
missing_value_cols
# Out:
# ['LandAverageTemperature',
#  'LandAverageTemperatureUncertainty',
#  'LandMaxTemperature',
#  'LandMaxTemperatureUncertainty',
#  'LandMinTemperature',
#  'LandMinTemperatureUncertainty',
#  'LandAndOceanAverageTemperature',
#  'LandAndOceanAverageTemperatureUncertainty']

# %%
for i in range(0, len(missing_value_cols)):
    col = missing_value_cols[i]
    print('' + str(col))
    global_temp_df[col] = global_temp_df[col].fillna(global_temp_df.groupby('year')[col].transform('mean'))
# Out:
# LandAverageTemperature
# LandAverageTemperatureUncertainty
# LandMaxTemperature
# LandMaxTemperatureUncertainty
# LandMinTemperature
# LandMinTemperatureUncertainty
# LandAndOceanAverageTemperature
# LandAndOceanAverageTemperatureUncertainty

# %%
global_temp_df.isnull().mean()
# Out:
# dt                                           0.00000
# LandAverageTemperature                       0.00000
# LandAverageTemperatureUncertainty            0.00000
# LandMaxTemperature                           0.37594
# LandMaxTemperatureUncertainty                0.37594
# LandMinTemperature                           0.37594
# LandMinTemperatureUncertainty                0.37594
# LandAndOceanAverageTemperature               0.37594
# LandAndOceanAverageTemperatureUncertainty    0.37594
# year                                         0.00000
# dtype: float64

# %%
global_temp_df.head()
# Out:
#           dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0 1750-01-01                   3.034                              3.574
# 1 1750-02-01                   3.083                              3.702
# 2 1750-03-01                   5.626                              3.076
# 3 1750-04-01                   8.490                              2.451
# 4 1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
global_temp_df = global_temp_df.iloc[:, [0,1,2,-1]]

# %%
global_temp_df.set_index('year', inplace=True)

# %% [markdown]
# ### visualizing data

# %%
global_temp_df.describe()
# Out:
#        LandAverageTemperature  LandAverageTemperatureUncertainty
# count             3192.000000                        3192.000000
# mean                 8.369337                           0.945719
# std                  4.374541                           1.100748
# min                 -2.080000                           0.034000
# 25%                  4.327750                           0.187000
# 50%                  8.587000                           0.394500
# 75%                 12.538750                           1.437250
# max                 19.021000                           7.880000

# %%
global_temp_df['LandAverageTemperaturePlusUncertainty'] = global_temp_df['LandAverageTemperature'] + global_temp_df['LandAverageTemperatureUncertainty']

# %%
global_temp_df['LandAverageTemperatureMinusUncertainty'] = global_temp_df['LandAverageTemperature'] - global_temp_df['LandAverageTemperatureUncertainty']

# %%
data = global_temp_df.drop(['LandAverageTemperatureUncertainty', 'dt'], axis=1)

# %%
plt.subplots(figsize=(20,10))

plt.title('Historical Global Temperature')

ax = sns.lineplot(data=data,ci=40, lw=3)

ax.set(xlabel='Year', ylabel='Land Average Temperature (ºC)')

plt.savefig('global_temp.pdf')

plt.show()

# %% [markdown]
# ### autocorr

# %%
shift_1 = global_temp_df['LandAverageTemperature'].autocorr(lag=1)
print(shift_1)
# Out:
# 0.8475862599639356

# %%
shift_2 = global_temp_df['LandAverageTemperature'].autocorr(lag=2)
print(shift_2)
# Out:
# 0.4935499356890492

# %%
shift_3 = global_temp_df['LandAverageTemperature'].autocorr(lag=10)
print(shift_3)
# Out:
# 0.4874303423922878

# %%
fig, ax = plt.subplots(figsize=(20,10))

ax = plot_acf(global_temp_df['LandAverageTemperature'], ax, title='Global Temperature Autocorrelation')

ax.savefig('global_temp_auto_corr.pdf')

plt.show()

# %% [markdown]
# ## decomposing time series

# %%
global_temp_df.set_index('dt', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-254-f696c9514fd2> in <module>
# ----> 1 global_temp_df.set_index('dt', inplace=True)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['dt'] are in the columns"

# %%
s_decomp = seasonal_decompose(global_temp_df['LandAverageTemperature'], model='additive')

# %%
plt.subplots(figsize=(20,10))
plt.title('Global Temperature Observed')
s_decomp.observed.plot()
plt.show()

# %%
plt.subplots(figsize=(20,10))
plt.title('Global Temperature Trend')
s_decomp.trend.plot()
plt.show()

# %%
plt.subplots(figsize=(20,10))
plt.title('Global Temperature Seasonality')
s_decomp.seasonal.plot()
plt.show()

# %%
plt.subplots(figsize=(20,10))
plt.title('Global Temperature Resid')
s_decomp.resid.plot()
plt.show()

# %%
trend = s_decomp.trend
seasonal = s_decomp.seasonal 
residual = s_decomp.resid

# %% [markdown]
# ## seasonality

# %% [raw]
# we can infer from the autocorrelation plot above that the global temperature has a sasonality (approx period of 12 years)

# %% [markdown]
# ## trend

# %% [raw]
# we can infer from the decomposition of time series that the data have a positive trend

# %% [markdown]
# ## stationary

# %% [raw]
# 1- The mean of the series should not be a function of time.
# 2- The variance of the series should not be a function of time. This property is known as homoscedasticity. Notice in the red graph the varying spread of data over time.
# 3- Covariance of the i th term and the (i + m) th term should not be a function of time.

# %% [raw]
# global temperature time series is not stationary:
#
# 1- mean increases overtime.
# 2- variance decreases overtime.
# 3- covariance between i and i + 12 is constant over time
